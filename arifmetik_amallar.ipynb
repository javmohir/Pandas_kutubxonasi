# %% [markdown]
# <a href="https://colab.research.google.com/github/javmohir/Pandas_kutubxonasi/blob/main/arifmetik_amallar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Ma'lumotlar tahlili. Pandas kutubxonasi.
#  Foydali funksiyalar (davomi)

# %% [markdown]
# Arifmetik amallar

# %% [markdown]
# Ikki Series yoki DataFrame obyektlari o'rtasida arifmetik amallar bajarishda indekslar juda muhim rol o'ynaydi.
#
# Amallar mos tushuvchi indekslar o'rtasida bajariladi. Agar obyektlarning birida mavjud indeks ikkinchisda yo'q bo'lsa natija NaN bo'ladi.

# %%
s1 = pd.Series([7.3, -2.5, 3.4, 1.5], index=['a', 'c', 'd', 'e'])
s2 = pd.Series([-2.1, 3.6, -1.5, 4, 3.1], index=['a', 'c', 'e', 'f', 'g'])

# %%
s1
# Out:
# a    7.3
# c   -2.5
# d    3.4
# e    1.5
# dtype: float64

# %%
s2
# Out:
# a   -2.1
# c    3.6
# e   -1.5
# f    4.0
# g    3.1
# dtype: float64

# %%
s1+s2
# Out:
# a    5.2
# c    1.1
# d    NaN
# e    0.0
# f    NaN
# g    NaN
# dtype: float64

# %% [markdown]
# E'tibor bering, s1 da mavjud d indeksi s2da mavjud bo'lmaganligi sabab s1+s2 da d indeksdagi qiymat NaN bo'ldi.
#
# Yuqoridagi holat DataFramelarga ham xos. Serieslardan farqli ravishda DataFrameda qator va ustun indekslari hisobga olinadi.

# %%
from numpy.core.fromnumeric import reshape
df1=pd.DataFrame(np.arange(9.).reshape(3,3), columns=list('abc'), index=['Olma','Anor','Uzum'])
df2=pd.DataFrame(np.arange(12.).reshape(4,3), columns=list('abd'), index=['Olma','Anor','Qovun','Anjir'])

# %%
df1
# Out:
#         a    b    c
# Olma  0.0  1.0  2.0
# Anor  3.0  4.0  5.0
# Uzum  6.0  7.0  8.0

# %%
df2
# Out:
#          a     b     d
# Olma   0.0   1.0   2.0
# Anor   3.0   4.0   5.0
# Qovun  6.0   7.0   8.0
# Anjir  9.0  10.0  11.0

# %%
df1+df2
# Out:
#          a    b   c   d
# Anjir  NaN  NaN NaN NaN
# Anor   6.0  8.0 NaN NaN
# Olma   0.0  2.0 NaN NaN
# Qovun  NaN  NaN NaN NaN
# Uzum   NaN  NaN NaN NaN

# %% [markdown]
# a va d ustunlar hamda Qovun va Anjir qatorlar ikkala DataFrameda bo'lmagani sababli yuqoridagi natija chiqdi
#
# Yuqoridagi qo'shish amalini .add() metodi yordamida ham bajarish mumkin.

# %%
df1.add(df2)
# Out:
#          a    b   c   d
# Anjir  NaN  NaN NaN NaN
# Anor   6.0  8.0 NaN NaN
# Olma   0.0  2.0 NaN NaN
# Qovun  NaN  NaN NaN NaN
# Uzum   NaN  NaN NaN NaN

# %% [markdown]
# Bunda maxsus fill_value parametri yordamida mos tushuvchi indekslardagi NaN qiymatlarni boshqa qiymat bilan almashtirish mumkin. Bu usulda yakuniy natijada ikkala df da ham mavjud bo'lmagan indekslarda NaN qiymati qoladi.

# %%
df1.add(df2, fill_value=0)
# Out:
#          a     b    c     d
# Anjir  9.0  10.0  NaN  11.0
# Anor   6.0   8.0  5.0   5.0
# Olma   0.0   2.0  2.0   2.0
# Qovun  6.0   7.0  NaN   8.0
# Uzum   6.0   7.0  8.0   NaN

# %% [markdown]
# Boshqa arifmetik amallar

# %% [markdown]
# add, radd - Qo'shish (+)
# sub, rsub - Ayirish (-)
# div, rdiv - Bo'lish (/)
# floordiv, rfloordiv - Bo'lish va butun qismini olis (//)
# mul, rmul - Ko'paytirish (*)
# pow, rpow - Eksponenta (**)
# Yuqoridagi amallarning barchasida fill_value parametri mavjud.
#
# rbilan boshlangan metodlarda DataFrame ifodaning o'ng tarafida bo'ladi.

# %%
df2.sub(df1, fill_value=0) # ayrish (-)
# Out:
#          a     b    c     d
# Anjir  9.0  10.0  NaN  11.0
# Anor   0.0   0.0 -5.0   5.0
# Olma   0.0   0.0 -2.0   2.0
# Qovun  6.0   7.0  NaN   8.0
# Uzum  -6.0  -7.0 -8.0   NaN

# %%
df1.rsub(df2, fill_value=0)
# Out:
#          a     b    c     d
# Anjir  9.0  10.0  NaN  11.0
# Anor   0.0   0.0 -5.0   5.0
# Olma   0.0   0.0 -2.0   2.0
# Qovun  6.0   7.0  NaN   8.0
# Uzum  -6.0  -7.0 -8.0   NaN

# %%
df2.div(df1)
# Out:
#          a    b   c   d
# Anjir  NaN  NaN NaN NaN
# Anor   1.0  1.0 NaN NaN
# Olma   NaN  1.0 NaN NaN
# Qovun  NaN  NaN NaN NaN
# Uzum   NaN  NaN NaN NaN

# %%
df2.rdiv(df1)# bo'lish(/)
# Out:
#          a    b   c   d
# Anjir  NaN  NaN NaN NaN
# Anor   1.0  1.0 NaN NaN
# Olma   NaN  1.0 NaN NaN
# Qovun  NaN  NaN NaN NaN
# Uzum   NaN  NaN NaN NaN

# %%
df2.mul(df1) #ko'paytirish
# Out:
#          a     b   c   d
# Anjir  NaN   NaN NaN NaN
# Anor   9.0  16.0 NaN NaN
# Olma   0.0   1.0 NaN NaN
# Qovun  NaN   NaN NaN NaN
# Uzum   NaN   NaN NaN NaN

# %%
df2.pow(df1)  # Eksponenta (**)
# Out:
#           a      b   c   d
# Anjir   NaN    NaN NaN NaN
# Anor   27.0  256.0 NaN NaN
# Olma    1.0    1.0 NaN NaN
# Qovun   NaN    NaN NaN NaN
# Uzum    NaN    NaN NaN NaN

# %% [markdown]
# DataFrame va Series o'rtasida arifmetik amallar

# %%
df_fig=pd.DataFrame(np.arange(1,13.).reshape(3,4), index=list('abc'), columns=['Olma','Anor','Qovun','Anjir'])
df_fig
# Out:
#    Olma  Anor  Qovun  Anjir
# a   1.0   2.0    3.0    4.0
# b   5.0   6.0    7.0    8.0
# c   9.0  10.0   11.0   12.0

# %%
obd=pd.Series([1,1,2,2], index=df_fig.columns)
obd
# Out:
# Olma     1
# Anor     1
# Qovun    2
# Anjir    2
# dtype: int64

# %%
df_fig-obd
# Out:
#    Olma  Anor  Qovun  Anjir
# a   0.0   1.0    1.0    2.0
# b   4.0   5.0    5.0    6.0
# c   8.0   9.0    9.0   10.0

# %%
df_fig+obd
# Out:
#    Olma  Anor  Qovun  Anjir
# a   2.0   3.0    5.0    6.0
# b   6.0   7.0    9.0   10.0
# c  10.0  11.0   13.0   14.0

# %%
obj1=pd.Series([1,3,2],index=['Olma','Uzum','Qovun'])
obj1
# Out:
# Olma     1
# Uzum     3
# Qovun    2
# dtype: int64

# %%
df_fig-obj1
# Out:
#    Anjir  Anor  Olma  Qovun  Uzum
# a    NaN   NaN   0.0    1.0   NaN
# b    NaN   NaN   4.0    5.0   NaN
# c    NaN   NaN   8.0    9.0   NaN

# %%
obj1['Olma']
# Out:
# 1

# %%
df_fig+obj1['Olma'] # omani qiymatini df_fig ni har bir qiymatiga qo'shish
# Out:
#    Olma  Anor  Qovun  Anjir
# a   2.0   3.0    4.0    5.0
# b   6.0   7.0    8.0    9.0
# c  10.0  11.0   12.0   13.0
