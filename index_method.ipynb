# %% [markdown]
# <a href="https://colab.research.google.com/github/javmohir/Pandas_kutubxonasi/blob/main/index_method.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame

# %%
data = {'Yil':[2021, 2020, 2019, 2018, 2017, 2016, 2015, 2010],
       'Aholi soni':[33.9, 33.5, 32.9, 32.5, 31.9, 31.4, 30.9, 28.5],
       "Temp":[1.54, 1.48, 1.56, 1.62, 1.65, 1.66, 1.64, 1.53]}
df = DataFrame(data, index=[21,20,19,18,17,16,15,10])

# %%
df
# Out:
#      Yil  Aholi soni  Temp
# 21  2021        33.9  1.54
# 20  2020        33.5  1.48
# 19  2019        32.9  1.56
# 18  2018        32.5  1.62
# 17  2017        31.9  1.65
# 16  2016        31.4  1.66
# 15  2015        30.9  1.64
# 10  2010        28.5  1.53

# %%
YAIM=[1700, 1670, 1600, 1590, 1400, 1300, 1350, 1360]

# %%
df['YAIM']=YAIM

# %%
df
# Out:
#      Yil  Aholi soni  Temp  YAIM
# 21  2021        33.9  1.54  1700
# 20  2020        33.5  1.48  1670
# 19  2019        32.9  1.56  1600
# 18  2018        32.5  1.62  1590
# 17  2017        31.9  1.65  1400
# 16  2016        31.4  1.66  1300
# 15  2015        30.9  1.64  1350
# 10  2010        28.5  1.53  1360

# %% [markdown]
# DataFrame yaratishning yana bir usuli lug'atlar lug'atidan foydalanish. Bunda tashqi lug'at kalitlari ustun, ichki lug'at kalitlari esa indeks bo'ladi.

# %%
data={'Uzbekistan':{2021:33.9, 2020:33.5, 2019:32.9, 2018:32.5, 2017:31.9},
      'Kazakhstan':{2021:18.9, 2020:18.7, 2019:18.5, 2018:18.3, 2017:18.1, 2016:17.8}}

# %%
df2=DataFrame(data)
df2
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %%
df2.index.name='yil'
df2
# Out:
#       Uzbekistan  Kazakhstan
# yil
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %% [markdown]
# Agar biz lug'atdan faqagina ma'lum bir qiymatlarni ajratib olishni istasak index ni o'zimiz ko'rsatishimiz mumkin.

# %%
df
# Out:
#     Yil  Aholi soni  Temp  YAIM
# 0  2021        33.9  1.54  1700
# 1  2020        33.5  1.48  1670
# 2  2019        32.9  1.56  1600
# 3  2018        32.5  1.62  1590
# 4  2017        31.9  1.65  1400
# 5  2016        31.4  1.66  1300
# 6  2015        30.9  1.64  1350
# 7  2010        28.5  1.53  1360

# %% [markdown]
# Index obyektining qiymatlarini o'zgartirib bo'lmaydi

# %%
data1 = {
    'Uzbekistan':{2021:33.9, 2020:33.5, 2019:32.9, 2018:32.5, 2017:31.9},
    'Kazakhstan':{2021:18.9, 2020:18.7, 2019:18.5, 2018:18.3, 2017:18.1, 2016:17.8}
}
df3 = pd.DataFrame(data)

# %%
df
# Out:
#      Yil  Aholi soni  Temp  YAIM
# 21  2021        33.9  1.54  1700
# 20  2020        33.5  1.48  1670
# 19  2019        32.9  1.56  1600
# 18  2018        32.5  1.62  1590
# 17  2017        31.9  1.65  1400
# 16  2016        31.4  1.66  1300
# 15  2015        30.9  1.64  1350
# 10  2010        28.5  1.53  1360

# %%
df.index
# Out:
# Int64Index([21, 20, 19, 18, 17, 16, 15, 10], dtype='int64')

# %%
indeks=df.columns

# %%
indeks
# Out:
# Index(['Yil', 'Aholi soni', 'Temp', 'YAIM'], dtype='object')

# %%
'Temp' in indeks
# Out:
# True

# %%
df3
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %%
'Tadjikistan' in df3.columns
# Out:
# False

# %%
2021 in df3.index
# Out:
# True

# %%
indeks[0]
# Out:
# 'Yil'

# %%
indeks[2:4]
# Out:
# Index(['Temp', 'YAIM'], dtype='object')

# %%
usernames = {"anvar":"anvarbek223", "olim":"olimtoy", "maryam":"mary334455","javohir":"javohir445"}
emails = {"anvar":"anvar@gmail.com", "olim":"olim@mail.ru", "maryam":"mary33@gmail.com","javohir":"javohir445@gmail.com"}

data = {
    'username':usernames,
    'email':emails
}
df4 = pd.DataFrame(data)

# %%
df4
# Out:
#             username                 email
# anvar    anvarbek223       anvar@gmail.com
# olim         olimtoy          olim@mail.ru
# maryam    mary334455      mary33@gmail.com
# javohir   javohir445  javohir445@gmail.com

# %%
df4.index
# Out:
# Index(['anvar', 'olim', 'maryam', 'javohir'], dtype='object')

# %%
arr=['anvar', 'olim', 'maryam', 'javohir']

# %%
arr[0]
# Out:
# 'anvar'

# %%
arr[2]
# Out:
# 'maryam'

# %%
data2={
     'username':{"olim":"olimjon21", "maryam":"maryam2020"},
    'email':{"olim":"olimjon21@mail.ru", "maryam":"maryam20@gmail.com"}
}

# %%
df5=df4.append(pd.DataFrame(data2))
# Out:
# <ipython-input-121-74e2a1b83881>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df5=df4.append(pd.DataFrame(data2))

# %%
df5
# Out:
#             username                 email
# anvar    anvarbek223       anvar@gmail.com
# olim         olimtoy          olim@mail.ru
# maryam    mary334455      mary33@gmail.com
# javohir   javohir445  javohir445@gmail.com
# olim       olimjon21     olimjon21@mail.ru
# maryam    maryam2020    maryam20@gmail.com

# %%
ind=[21,20,19,18,17,16,15,10]
ind.sort()
ind
# Out:
# [10, 15, 16, 17, 18, 19, 20, 21]

# %%
df.reindex(ind) #.reindex() indekslar o'rnini almashtirish
# Out:
#      Yil  Aholi soni  Temp  YAIM
# 10  2010        28.5  1.53  1360
# 15  2015        30.9  1.64  1350
# 16  2016        31.4  1.66  1300
# 17  2017        31.9  1.65  1400
# 18  2018        32.5  1.62  1590
# 19  2019        32.9  1.56  1600
# 20  2020        33.5  1.48  1670
# 21  2021        33.9  1.54  1700

# %%
df.reindex([10,16,18])
# Out:
#      Yil  Aholi soni  Temp  YAIM
# 10  2010        28.5  1.53  1360
# 16  2016        31.4  1.66  1300
# 18  2018        32.5  1.62  1590

# %%
df.reindex(index=range(10,22), method='nearest') # 'nearest' bo'sh qatorni eng yaqin qiymat bilan to'ldirish
# Out:
#      Yil  Aholi soni  Temp  YAIM
# 10  2010        28.5  1.53  1360
# 11  2010        28.5  1.53  1360
# 12  2010        28.5  1.53  1360
# 13  2015        30.9  1.64  1350
# 14  2015        30.9  1.64  1350
# 15  2015        30.9  1.64  1350
# 16  2016        31.4  1.66  1300
# 17  2017        31.9  1.65  1400
# 18  2018        32.5  1.62  1590
# 19  2019        32.9  1.56  1600
# 20  2020        33.5  1.48  1670
# 21  2021        33.9  1.54  1700

# %%
df.reindex(index=range(10,22), method='ffill') # bo'sh qatorni eng oxirgi qiymat bilan to'ldiradi.
# Out:
#      Yil  Aholi soni  Temp  YAIM
# 10  2010        28.5  1.53  1360
# 11  2015        30.9  1.64  1350
# 12  2015        30.9  1.64  1350
# 13  2015        30.9  1.64  1350
# 14  2015        30.9  1.64  1350
# 15  2015        30.9  1.64  1350
# 16  2016        31.4  1.66  1300
# 17  2017        31.9  1.65  1400
# 18  2018        32.5  1.62  1590
# 19  2019        32.9  1.56  1600
# 20  2020        33.5  1.48  1670
# 21  2021        33.9  1.54  1700

# %%
df.reindex(columns=['Aholi soni', 'Temp', 'YAIM'])
# Out:
#     Aholi soni  Temp  YAIM
# 21        33.9  1.54  1700
# 20        33.5  1.48  1670
# 19        32.9  1.56  1600
# 18        32.5  1.62  1590
# 17        31.9  1.65  1400
# 16        31.4  1.66  1300
# 15        30.9  1.64  1350
# 10        28.5  1.53  1360

# %%
df.loc[[10,15,20],['Aholi soni', 'Temp']]
# Out:
#     Aholi soni  Temp
# 10        28.5  1.53
# 15        30.9  1.64
# 20        33.5  1.48
