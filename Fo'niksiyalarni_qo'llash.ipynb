# %% [markdown]
# <a href="https://colab.research.google.com/github/javmohir/Pandas_kutubxonasi/blob/main/Fo'niksiyalarni_qo'llash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
#  Obyekti elementlariga Funksiyalarni qo'llash

# %%
df = pd.DataFrame(np.random.randn(3,4), index=list('abc'), columns=['Olma','Anor','Qovun','Anjir'])
df
# Out:
#        Olma      Anor     Qovun     Anjir
# a  1.243576 -0.140103 -1.736930 -0.003696
# b -0.857355 -0.807505  0.510161  0.708697
# c  0.306499  1.423877  0.760871  1.171992

# %% [markdown]
# Biror funksiyani DF barcha elementlariga qo'llash:

# %%
np.abs(df)
# Out:
#        Olma      Anor     Qovun     Anjir
# a  1.243576  0.140103  1.736930  0.003696
# b  0.857355  0.807505  0.510161  0.708697
# c  0.306499  1.423877  0.760871  1.171992

# %%
np.round(df)
# Out:
#    Olma  Anor  Qovun  Anjir
# a   1.0  -0.0   -2.0   -0.0
# b  -1.0  -1.0    1.0    1.0
# c   0.0   1.0    1.0    1.0

# %%
df.mean()
# Out:
# Olma     0.230906
# Anor     0.158756
# Qovun   -0.155299
# Anjir    0.625664
# dtype: float64

# %% [markdown]
# Yuqoridagi funksiyalarni .apply() metodi yordamida ham qo'llash mumkin.

# %%
df
# Out:
#        Olma      Anor     Qovun     Anjir
# a  1.243576 -0.140103 -1.736930 -0.003696
# b -0.857355 -0.807505  0.510161  0.708697
# c  0.306499  1.423877  0.760871  1.171992

# %%
df.apply(np.mean)
# Out:
# Olma     0.230906
# Anor     0.158756
# Qovun   -0.155299
# Anjir    0.625664
# dtype: float64

# %%
df.apply(np.sum, axis='columns')
# Out:
# a   -0.637153
# b   -0.446003
# c    3.663240
# dtype: float64

# %%
# DF qatori max va min qiymati ayirmasini hisoblaydigan funksiya
f = lambda x: x.max() - x.min()

# %% [markdown]
# Bu metodning afzalligi, o'zingiz istalgan funksiyani yozib uni DF elementlariga qo'llashigniz mumkin:

# %%
df.apply(f)
# Out:
# Olma     2.100931
# Anor     2.231383
# Qovun    2.497801
# Anjir    1.175688
# dtype: float64

# %% [markdown]
# Funksiya nafaqat yagona qiymat, balki series obyektini ham qaytarishi mumkin

# %%
def foo(x):
    return pd.Series([x.min(), x.max()], index=['min', 'max'])

# %%
df.apply(foo)
# Out:
#          Olma      Anor     Qovun     Anjir
# min -0.857355 -0.807505 -1.736930 -0.003696
# max  1.243576  1.423877  0.760871  1.171992

# %% [markdown]
# Biror funksiyani DF har bir elementiga alohida qo'llash uchun .applymap() metodidan foydalaning.

# %%
f = lambda x : x*x # qiymatni kvadratga oshiruvchi funksiya

# %%
df = pd.DataFrame(np.arange(1,13).reshape(3,4), index=list('abc'), columns=['Olma','Anor','Qovun','Anjir'])
df
# Out:
#    Olma  Anor  Qovun  Anjir
# a     1     2      3      4
# b     5     6      7      8
# c     9    10     11     12

# %%
df.applymap(f)
# Out:
#    Olma  Anor  Qovun  Anjir
# a     1     4      9     16
# b    25    36     49     64
# c    81   100    121    144
